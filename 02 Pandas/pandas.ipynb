# %% [markdown]
# <a href="https://colab.research.google.com/github/sumpumm/ML-from-scratch/blob/main/02%20Pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas
#
# Data preprocessing in Machine Learning using pandas.
#
# Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# Pandas is an open source Python package that is most widely used for data science/ data analysis and machine learning models.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
data={
    "cars":["bmw","honda","suzuki","BYD"],
    "models":["2007","2009","2008","2023"],
    "passenger":["5", "5","6","7"]
}
# print(data)
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'BYD'],
#  'models': ['2007', '2009', '2008', '2023'],
#  'passenger': ['5', '5', '6', '7']}

# %%
#convert to data frame
df=pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     bmw   2007         5
# 1   honda   2009         5
# 2  suzuki   2008         6
# 3     BYD   2023         7

# %%
#save the file as csv file
df.to_csv("/content/drive/MyDrive/Colab Notebooks/data/cars.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#pandas series

import pandas as pd

a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#create lebels in pandas with index
a=[1,7,2]
myvar= pd.Series(a,index=["x","y",'z'])
# print(myvar)
myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 7

# %%
#task : create a dataframe named df with data calories and duration
import pandas as pd

data={
    "calories":[420,380,390],
    "duration":[50,40,45]
}
df=pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[1])
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
import pandas as pd

data={
    "calories":[420,380,390],
    "duration":[50,40,45]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc['day2'])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64
